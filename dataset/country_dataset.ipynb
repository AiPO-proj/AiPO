# %%
import os
import csv
import time
import requests
import geopandas as gpd
from shapely.geometry import box, Point
from shapely.ops import unary_union

# %%
MAPILLARY_ACCESS_TOKEN = "MLY|29607086385604993|05c6b7344dbbb999b79bd9a6ce3a0145"
OUTPUT_DIR = "country_dataset"
CSV_FILENAME = "country_dataset.csv"
IMAGES_PER_COUNTRY = 100
MAX_RETRIES = 3

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
countries = gpd.read_file("natural_earth/ne_110m_admin_0_countries.shp")

# %%
def fetch_mapillary_images_bbox(bbox, limit=100, retries=MAX_RETRIES):
    """Pobiera listę zdjęć z Mapillary w danym bbox.
    bbox = (min_lon, min_lat, max_lon, max_lat)
    """
    url = (
        f"https://graph.mapillary.com/images"
        f"?access_token={MAPILLARY_ACCESS_TOKEN}"
        f"&fields=id,thumb_1024_url,geometry"
        f"&limit={limit}"
        f"&bbox={bbox[0]},{bbox[1]},{bbox[2]},{bbox[3]}"
    )
    for attempt in range(retries):
        try:
            r = requests.get(url, timeout=30)
            r.raise_for_status()
            data = r.json()
            return data.get("data", [])
        except Exception as e:
            print(f"  [Błąd API Mapillary, próba {attempt+1}/{retries}] {e}")
            time.sleep(5)
    return []

# %%
def download_image(url, path):
    try:
        r = requests.get(url, timeout=15)
        r.raise_for_status()
        with open(path, "wb") as f:
            f.write(r.content)
        return True
    except Exception as e:
        print(f"  Błąd pobierania: {e}")
        return False

# %%
with open(CSV_FILENAME, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["country", "latitude", "longitude", "local_path"])

    for idx, country_row in countries.iterrows():
        country_name = country_row["NAME"]
        country_geom = country_row["geometry"]

        print(f"\n🌍 Przetwarzanie kraju: {country_name}")

        # Bounding box kraju
        minx, miny, maxx, maxy = country_geom.bounds
        bbox = (minx, miny, maxx, maxy)

        country_dir = os.path.join(OUTPUT_DIR, country_name.replace(" ", "_"))
        os.makedirs(country_dir, exist_ok=True)

        images = fetch_mapillary_images_bbox(bbox, limit=IMAGES_PER_COUNTRY*2) 
        if not images:
            print(f"  ❌ Brak zdjęć w obszarze bbox kraju {country_name}")
            continue

        saved = 0
        for image in images:
            # Sprawdź, czy punkt znajduje się wewnątrz granicy kraju (nie tylko w bbox)
            coords = image.get("geometry", {}).get("coordinates", None)
            if coords is None:
                continue
            point = Point(coords)
            if not country_geom.contains(point):
                continue

            image_id = image["id"]
            image_url = image.get("thumb_1024_url")
            if not image_url:
                continue

            filename = f"{image_id}.jpg"
            local_path = os.path.join(country_dir, filename)

            if download_image(image_url, local_path):
                lat, lon = point.y, point.x
                writer.writerow([country_name, lat, lon, local_path])
                #print(f" Pobrano {saved+1}: {filename} ({lat:.5f}, {lon:.5f})")
                saved += 1

            if saved >= IMAGES_PER_COUNTRY:
                break
            time.sleep(0.2)

        if saved == 0:
            print(f"  ❌ Nie znaleziono zdjęć wewnątrz granicy kraju {country_name}")

print("\nZakończono tworzenie datasetu!")
print(f"Dane zapisane w: {os.path.abspath(OUTPUT_DIR)} i {os.path.abspath(CSV_FILENAME)}")
# Out:
# 🌍 Przetwarzanie kraju: Fiji
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Fiji
#
# 🌍 Przetwarzanie kraju: Tanzania
#
# 🌍 Przetwarzanie kraju: W. Sahara
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju W. Sahara
#
# 🌍 Przetwarzanie kraju: Canada
#
# 🌍 Przetwarzanie kraju: United States of America
#
# 🌍 Przetwarzanie kraju: Kazakhstan
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Kazakhstan
#
# 🌍 Przetwarzanie kraju: Uzbekistan
#
# 🌍 Przetwarzanie kraju: Papua New Guinea
#
# 🌍 Przetwarzanie kraju: Indonesia
#
# 🌍 Przetwarzanie kraju: Argentina
#
# 🌍 Przetwarzanie kraju: Chile
#
# 🌍 Przetwarzanie kraju: Dem. Rep. Congo
#
# 🌍 Przetwarzanie kraju: Somalia
#
# 🌍 Przetwarzanie kraju: Kenya
#
# 🌍 Przetwarzanie kraju: Sudan
#
# 🌍 Przetwarzanie kraju: Chad
#
# 🌍 Przetwarzanie kraju: Haiti
#
# 🌍 Przetwarzanie kraju: Dominican Rep.
#
# 🌍 Przetwarzanie kraju: Russia
#   [Błąd API Mapillary, próba 1/3] 500 Server Error: Internal Server Error for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=-180.0,41.15141612402135,180.00000000000006,81.2504
#   [Błąd API Mapillary, próba 2/3] 500 Server Error: Internal Server Error for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=-180.0,41.15141612402135,180.00000000000006,81.2504
#   [Błąd API Mapillary, próba 3/3] 500 Server Error: Internal Server Error for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=-180.0,41.15141612402135,180.00000000000006,81.2504
#   ❌ Brak zdjęć w obszarze bbox kraju Russia
#
# 🌍 Przetwarzanie kraju: Bahamas
#
# 🌍 Przetwarzanie kraju: Falkland Is.
#
# 🌍 Przetwarzanie kraju: Norway
#
# 🌍 Przetwarzanie kraju: Greenland
#
# 🌍 Przetwarzanie kraju: Fr. S. Antarctic Lands
#   ❌ Brak zdjęć w obszarze bbox kraju Fr. S. Antarctic Lands
#
# 🌍 Przetwarzanie kraju: Timor-Leste
#
# 🌍 Przetwarzanie kraju: South Africa
#
# 🌍 Przetwarzanie kraju: Lesotho
#
# 🌍 Przetwarzanie kraju: Mexico
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Mexico
#
# 🌍 Przetwarzanie kraju: Uruguay
#
# 🌍 Przetwarzanie kraju: Brazil
#
# 🌍 Przetwarzanie kraju: Bolivia
#
# 🌍 Przetwarzanie kraju: Peru
#
# 🌍 Przetwarzanie kraju: Colombia
#
# 🌍 Przetwarzanie kraju: Panama
#
# 🌍 Przetwarzanie kraju: Costa Rica
#
# 🌍 Przetwarzanie kraju: Nicaragua
#
# 🌍 Przetwarzanie kraju: Honduras
#
# 🌍 Przetwarzanie kraju: El Salvador
#
# 🌍 Przetwarzanie kraju: Guatemala
#
# 🌍 Przetwarzanie kraju: Belize
#
# 🌍 Przetwarzanie kraju: Venezuela
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Venezuela
#
# 🌍 Przetwarzanie kraju: Guyana
#
# 🌍 Przetwarzanie kraju: Suriname
#
# 🌍 Przetwarzanie kraju: France
#
# 🌍 Przetwarzanie kraju: Ecuador
#
# 🌍 Przetwarzanie kraju: Puerto Rico
#
# 🌍 Przetwarzanie kraju: Jamaica
#
# 🌍 Przetwarzanie kraju: Cuba
#   [Błąd API Mapillary, próba 1/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=-84.97491105827311,19.855480861891877,-74.17802486845126,23.188610744717707
#   [Błąd API Mapillary, próba 2/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=-84.97491105827311,19.855480861891877,-74.17802486845126,23.188610744717707
#   [Błąd API Mapillary, próba 3/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=-84.97491105827311,19.855480861891877,-74.17802486845126,23.188610744717707
#   ❌ Brak zdjęć w obszarze bbox kraju Cuba
#
# 🌍 Przetwarzanie kraju: Zimbabwe
#   [Błąd API Mapillary, próba 1/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=25.264225701608012,-22.271611830333935,32.84986087416439,-15.507786960515213
#   [Błąd API Mapillary, próba 2/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=25.264225701608012,-22.271611830333935,32.84986087416439,-15.507786960515213
#
# 🌍 Przetwarzanie kraju: Botswana
#   [Błąd API Mapillary, próba 1/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=19.89545779794068,-26.828542982695915,29.43218834810904,-17.661815687737374
#   [Błąd API Mapillary, próba 2/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=19.89545779794068,-26.828542982695915,29.43218834810904,-17.661815687737374
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Botswana
#
# 🌍 Przetwarzanie kraju: Namibia
#   [Błąd API Mapillary, próba 1/3] 400 Client Error: Bad Request for url: https://graph.mapillary.com/images?access_token=MLY%7C29607086385604993%7C05c6b7344dbbb999b79bd9a6ce3a0145&fields=id,thumb_1024_url,geometry&limit=200&bbox=11.734198846085121,-29.04546192801728,25.08444339366457,-16.94134286872407
#
# 🌍 Przetwarzanie kraju: Senegal
#
# 🌍 Przetwarzanie kraju: Mali
#
# 🌍 Przetwarzanie kraju: Mauritania
#
# 🌍 Przetwarzanie kraju: Benin
#
# 🌍 Przetwarzanie kraju: Niger
#
# 🌍 Przetwarzanie kraju: Nigeria
#
# 🌍 Przetwarzanie kraju: Cameroon
#
# 🌍 Przetwarzanie kraju: Togo
#
# 🌍 Przetwarzanie kraju: Ghana
#
# 🌍 Przetwarzanie kraju: Côte d'Ivoire
#
# 🌍 Przetwarzanie kraju: Guinea
#
# 🌍 Przetwarzanie kraju: Guinea-Bissau
#
# 🌍 Przetwarzanie kraju: Liberia
#
# 🌍 Przetwarzanie kraju: Sierra Leone
#
# 🌍 Przetwarzanie kraju: Burkina Faso
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Burkina Faso
#
# 🌍 Przetwarzanie kraju: Central African Rep.
#
# 🌍 Przetwarzanie kraju: Congo
#
# 🌍 Przetwarzanie kraju: Gabon
#
# 🌍 Przetwarzanie kraju: Eq. Guinea
#
# 🌍 Przetwarzanie kraju: Zambia
#
# 🌍 Przetwarzanie kraju: Malawi
#
# 🌍 Przetwarzanie kraju: Mozambique
#
# 🌍 Przetwarzanie kraju: eSwatini
#
# 🌍 Przetwarzanie kraju: Angola
#
# 🌍 Przetwarzanie kraju: Burundi
#
# 🌍 Przetwarzanie kraju: Israel
#
# 🌍 Przetwarzanie kraju: Lebanon
#
# 🌍 Przetwarzanie kraju: Madagascar
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Madagascar
#
# 🌍 Przetwarzanie kraju: Palestine
#
# 🌍 Przetwarzanie kraju: Gambia
#
# 🌍 Przetwarzanie kraju: Tunisia
#
# 🌍 Przetwarzanie kraju: Algeria
#
# 🌍 Przetwarzanie kraju: Jordan
#
# 🌍 Przetwarzanie kraju: United Arab Emirates
#
# 🌍 Przetwarzanie kraju: Qatar
#
# 🌍 Przetwarzanie kraju: Kuwait
#
# 🌍 Przetwarzanie kraju: Iraq
#
# 🌍 Przetwarzanie kraju: Oman
#
# 🌍 Przetwarzanie kraju: Vanuatu
#
# 🌍 Przetwarzanie kraju: Cambodia
#
# 🌍 Przetwarzanie kraju: Thailand
#
# 🌍 Przetwarzanie kraju: Laos
#
# 🌍 Przetwarzanie kraju: Myanmar
#
# 🌍 Przetwarzanie kraju: Vietnam
#
# 🌍 Przetwarzanie kraju: North Korea
#
# 🌍 Przetwarzanie kraju: South Korea
#
# 🌍 Przetwarzanie kraju: Mongolia
#
# 🌍 Przetwarzanie kraju: India
#
# 🌍 Przetwarzanie kraju: Bangladesh
#
# 🌍 Przetwarzanie kraju: Bhutan
#
# 🌍 Przetwarzanie kraju: Nepal
#
# 🌍 Przetwarzanie kraju: Pakistan
#
# 🌍 Przetwarzanie kraju: Afghanistan
#
# 🌍 Przetwarzanie kraju: Tajikistan
#
# 🌍 Przetwarzanie kraju: Kyrgyzstan
#
# 🌍 Przetwarzanie kraju: Turkmenistan
#
# 🌍 Przetwarzanie kraju: Iran
#
# 🌍 Przetwarzanie kraju: Syria
#
# 🌍 Przetwarzanie kraju: Armenia
#
# 🌍 Przetwarzanie kraju: Sweden
#
# 🌍 Przetwarzanie kraju: Belarus
#
# 🌍 Przetwarzanie kraju: Ukraine
#
# 🌍 Przetwarzanie kraju: Poland
#
# 🌍 Przetwarzanie kraju: Austria
#
# 🌍 Przetwarzanie kraju: Hungary
#
# 🌍 Przetwarzanie kraju: Moldova
#
# 🌍 Przetwarzanie kraju: Romania
#
# 🌍 Przetwarzanie kraju: Lithuania
#
# 🌍 Przetwarzanie kraju: Latvia
#
# 🌍 Przetwarzanie kraju: Estonia
#
# 🌍 Przetwarzanie kraju: Germany
#
# 🌍 Przetwarzanie kraju: Bulgaria
#
# 🌍 Przetwarzanie kraju: Greece
#
# 🌍 Przetwarzanie kraju: Turkey
#
# 🌍 Przetwarzanie kraju: Albania
#
# 🌍 Przetwarzanie kraju: Croatia
#
# 🌍 Przetwarzanie kraju: Switzerland
#
# 🌍 Przetwarzanie kraju: Luxembourg
#
# 🌍 Przetwarzanie kraju: Belgium
#
# 🌍 Przetwarzanie kraju: Netherlands
#   Błąd pobierania: HTTPSConnectionPool(host='scontent.fwaw3-2.fna.fbcdn.net', port=443): Read timed out. (read timeout=15)
#   Błąd pobierania: HTTPSConnectionPool(host='scontent.fwaw3-2.fna.fbcdn.net', port=443): Read timed out. (read timeout=15)
#
# 🌍 Przetwarzanie kraju: Portugal
#   Błąd pobierania: HTTPSConnectionPool(host='scontent.fwaw3-2.fna.fbcdn.net', port=443): Read timed out. (read timeout=15)
#   Błąd pobierania: HTTPSConnectionPool(host='scontent.fwaw3-2.fna.fbcdn.net', port=443): Read timed out. (read timeout=15)
#
# 🌍 Przetwarzanie kraju: Spain
#
# 🌍 Przetwarzanie kraju: Ireland
#
# 🌍 Przetwarzanie kraju: New Caledonia
#
# 🌍 Przetwarzanie kraju: Solomon Is.
#
# 🌍 Przetwarzanie kraju: New Zealand
#
# 🌍 Przetwarzanie kraju: Australia
#
# 🌍 Przetwarzanie kraju: Sri Lanka
#
# 🌍 Przetwarzanie kraju: China
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju China
#
# 🌍 Przetwarzanie kraju: Taiwan
#
# 🌍 Przetwarzanie kraju: Italy
#
# 🌍 Przetwarzanie kraju: Denmark
#
# 🌍 Przetwarzanie kraju: United Kingdom
#
# 🌍 Przetwarzanie kraju: Iceland
#
# 🌍 Przetwarzanie kraju: Azerbaijan
#
# 🌍 Przetwarzanie kraju: Georgia
#
# 🌍 Przetwarzanie kraju: Philippines
#
# 🌍 Przetwarzanie kraju: Malaysia
#
# 🌍 Przetwarzanie kraju: Brunei
#
# 🌍 Przetwarzanie kraju: Slovenia
#
# 🌍 Przetwarzanie kraju: Finland
#
# 🌍 Przetwarzanie kraju: Slovakia
#
# 🌍 Przetwarzanie kraju: Czechia
#
# 🌍 Przetwarzanie kraju: Eritrea
#   ❌ Nie znaleziono zdjęć wewnątrz granicy kraju Eritrea
#
# 🌍 Przetwarzanie kraju: Japan
#
# 🌍 Przetwarzanie kraju: Paraguay
#
# 🌍 Przetwarzanie kraju: Yemen
#
# 🌍 Przetwarzanie kraju: Saudi Arabia
#
# 🌍 Przetwarzanie kraju: Antarctica
#
# 🌍 Przetwarzanie kraju: N. Cyprus
#
# 🌍 Przetwarzanie kraju: Cyprus
#
# 🌍 Przetwarzanie kraju: Morocco
#
# 🌍 Przetwarzanie kraju: Egypt
#
# 🌍 Przetwarzanie kraju: Libya
#
# 🌍 Przetwarzanie kraju: Ethiopia
#
# 🌍 Przetwarzanie kraju: Djibouti
#
# 🌍 Przetwarzanie kraju: Somaliland
#
# 🌍 Przetwarzanie kraju: Uganda
#
# 🌍 Przetwarzanie kraju: Rwanda
#
# 🌍 Przetwarzanie kraju: Bosnia and Herz.
#
# 🌍 Przetwarzanie kraju: North Macedonia
#
# 🌍 Przetwarzanie kraju: Serbia
#
# 🌍 Przetwarzanie kraju: Montenegro
#
# 🌍 Przetwarzanie kraju: Kosovo
#
# 🌍 Przetwarzanie kraju: Trinidad and Tobago
#
# 🌍 Przetwarzanie kraju: S. Sudan
#
# Zakończono tworzenie datasetu!
# Dane zapisane w: c:\Users\barte\Desktop\Bartek_stuff\AiPO\country_dataset i c:\Users\barte\Desktop\Bartek_stuff\AiPO\country_dataset.csv
